# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
url = 'C:/Users/rupak/OneDrive/Desktop/Machine-Learning/ECB.csv'
ecb = pd.read_csv(url)
ecb.head()
# Out:
#          DATE TIME PERIOD  TRANSACTIONS
# 0  31-10-1997     1997Oct          5804
# 1  30-11-1997     1997Nov          9881
# 2  31-12-1997     1997Dec        -16977
# 3  31-01-1998     1998Jan         22191
# 4  28-02-1998     1998Feb         19626

# %%
print(ecb)
# Out:
#            DATE TIME PERIOD  TRANSACTIONS
# 0    31-10-1997     1997Oct          5804
# 1    30-11-1997     1997Nov          9881
# 2    31-12-1997     1997Dec        -16977
# 3    31-01-1998     1998Jan         22191
# 4    28-02-1998     1998Feb         19626
# ..          ...         ...           ...
# 312  31-10-2023     2023Oct          6449
# 313  30-11-2023     2023Nov          4589
# 314  31-12-2023     2023Dec        -16424
# 315  31-01-2024     2024Jan         16349
# 316  29-02-2024     2024Feb         35130
#
# [317 rows x 3 columns]

# %%
sb.countplot(x='TRANSACTIONS',data=ecb)
plt.show()

# %%
sb.boxplot(x='TRANSACTIONS', y='DATE', data=ecb, palette='hls')
ecb.head()
plt.show()
